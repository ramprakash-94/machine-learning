# %%
import random
from environment import Agent, Environment
from planner import RoutePlanner
from simulator import Simulator
import pandas as pd
import numpy as np

class LearningAgent(Agent):
    """An agent that learns to drive in the smartcab world."""
    def set_alphagamma(self, al=0, ga=0):
        self.alpha = al
        self.gamma = ga

    def __init__(self, env):
        super(LearningAgent, self).__init__(env)  # sets self.env = env, state = None, next_waypoint = None, and a default color
        self.color = 'red'  # override color
        self.planner = RoutePlanner(self.env, self)  # simple route planner to get next_waypoint
        # TODO: Initialize any additional variables here
        self.Q = {}
        #self.alpha = 0.9
        #self.gamma = 0.33
        self.epsilon = 0.1
        self.net_reward = 0
        self.succ=0


    def reset(self, destination=None):
        self.planner.route_to(destination)
        # TODO: Prepare for a new trip; reset any variables here, if required
        self.p_state = None
        self.p_action = None
        self.p_reward = None
        self.p_net_reward = 0
        self.net_reward = 0

    def update(self, t):
        # Gather inputs
        self.next_waypoint = self.planner.next_waypoint()  # from route planner, also displayed by simulator
        inputs = self.env.sense(self)
        deadline = self.env.get_deadline(self)
        # TODO: Update state
        inputs['waypoint'] = self.next_waypoint
        
        del inputs['left']
        del inputs['right']
        del inputs['oncoming']
        self.state = tuple(sorted(inputs.items()))

        # TODO: Select action according to your policy
        action = ""
        #action = random.choice(self.Environment.valid_actions)
        Qval, action = self.pickQact(self.state)

        # Execute action and get reward
        reward = self.env.act(self, action)

        # TODO: Learn policy based on state, action, reward
        if self.p_state != None:
            if (self.p_state, self.p_action) not in self.Q:
                self.Q[(self.p_state, self.p_action)] = 0

            self.Q[(self.p_state, self.p_action)] = (1-self.alpha) * self.Q[(self.p_state, self.p_action)] + self.alpha*(self.p_reward + self.gamma * self.pickQact(self.state)[0]) 


        #checks if the trip was succesful and increments the count of number of successful trips
        if self.env.done:
            self.succ += 1

        #Setting current parameters as previous parameters
        self.p_state = self.state
        self.p_action = action
        self.p_reward = reward

        print "LearningAgent.update(): deadline = {}, inputs = {}, action = {}, reward = {}, success = {}".format(deadline, inputs, action, reward, self.succ)  # [debug]
        print "alpha = {}, gamma{}".format(self.alpha,self.gamma)
    #Checks if a Q value exists in the Q matrix for the given (state, action) pair     
    def getQval(self, state, action):
        if (state, action) not in self.Q:
            self.Q[(state, action)] = 0
        return self.Q[(state,action)]   

    def pickQact(self, state):
         b_action = random.choice(Environment.valid_actions)
         if self.epsilon > random.random():
            maxQ = self.getQval(state, b_action)
         else:
            maxQ = -999999999
            for a in Environment.valid_actions:
                q = self.getQval(state, a)
                if q > maxQ:
                    maxQ = q
                    b_action = a
                elif q==maxQ:
                    if self.epsilon > random.random():
                        b_action = a

         return (maxQ, b_action) 




def pass_al_ga(al=0,ga=0):
    # Set up environment and agent
    e = Environment()  # create environment (also adds some dummy traffic)
    a = e.create_agent(LearningAgent)  # create agent
    e.set_primary_agent(a, enforce_deadline=True)  # specify agent to track
    a.set_alphagamma(al,ga)
    # NOTE: You can set enforce_deadline=False while debugging to allow longer trials

    # Now simulate it
    sim = Simulator(e, update_delay=0.5, display=True)  # create simulator (uses pygame when display=True, if available)
    # NOTE: To speed up simulation, reduce update_delay and/or set display=False
    sim.run(n_trials=100)
    return a.succ

def run():
    """Run the agent for a finite number of trials."""
    O = {}
    #alpha_val = [0.1, 0.3, 0.5, 0.7, 0.9]
    #gamma_val = [0.1, 0.3, 0.5, 0.7, 0.9]
    #for al in alpha_val:
    #    for ga in gamma_val:
    val = {(0.1,0.3),(0.1,0.7),(0.3,0.5),(0.5,0.9),(0.7,0.1),(0.9,0.9)}

    O[(0.1,0.3)] = pass_al_ga(0.1,0.3)
    O[(0.1,0.7)] = pass_al_ga(0.1,0.7)
    O[(0.3,0.5)] = pass_al_ga(0.3,0.5)       
    O[(0.5,0.9)] = pass_al_ga(0.5,0.9)
    O[(0.7,0.1)] = pass_al_ga(0.7,0.1)
    #O[(0.9,0.9)] = pass_al_ga(0.9,0.9)
    print "Results\n"        
    for v in val:
        
        print "Alpha, Gamma:{}, Successful Trials:{}".format(val, O[val])  

    #pd.DataFrame(O).to_csv('output.csv',sep=',')       
      # run for a specified number of trials
    # NOTE: To quit midway, press Esc or close pygame window, or hit Ctrl+C on the command-line


if __name__ == '__main__':
    run()
# Out:
# Simulator.__init__(): Error initializing GUI objects; display disabled.
# error: Couldn't open images/car-cyan.png
# Simulator.run(): Trial 0
# Environment.reset(): Trial set up with start = (5, 3), destination = (3, 6), deadline = 25
# RoutePlanner.route_to(): destination = (3, 6)
# LearningAgent.update(): deadline = 25, inputs = {'light': 'red', 'waypoint': 'forward'}, action = forward, reward = -1.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 24, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 23, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 22, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 21, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 20, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 19, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 18, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 17, inputs = {'light': 'red', 'waypoint': 'forward'}, action = forward, reward = -1.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 16, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 15, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 14, inputs = {'light': 'green', 'waypoint': 'left'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 13, inputs = {'light': 'red', 'waypoint': 'left'}, action = left, reward = -1.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 12, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 11, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 10, inputs = {'light': 'red', 'waypoint': 'left'}, action = right, reward = -0.5, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 9, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 8, inputs = {'light': 'red', 'waypoint': 'right'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 7, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 6, inputs = {'light': 'green', 'waypoint': 'right'}, action = right, reward = 2.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 5, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 4, inputs = {'light': 'red', 'waypoint': 'left'}, action = forward, reward = -1.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 3, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 2, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 1, inputs = {'light': 'green', 'waypoint': 'left'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 0, inputs = {'light': 'green', 'waypoint': 'left'}, action = right, reward = -0.5, success = 0
# alpha = 0.1, gamma0.3
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Simulator.run(): Trial 1
# Environment.reset(): Trial set up with start = (6, 2), destination = (3, 1), deadline = 20
# RoutePlanner.route_to(): destination = (3, 1)
# LearningAgent.update(): deadline = 20, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 19, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 18, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 17, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 16, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 15, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 0
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 14, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 0
# alpha = 0.1, gamma0.3
# Environment.act(): Primary agent has reached destination!
# LearningAgent.update(): deadline = 13, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 12.0, success = 1
# alpha = 0.1, gamma0.3
# Simulator.run(): Trial 2
# Environment.reset(): Trial set up with start = (3, 3), destination = (5, 1), deadline = 20
# RoutePlanner.route_to(): destination = (5, 1)
# LearningAgent.update(): deadline = 20, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 1
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 19, inputs = {'light': 'green', 'waypoint': 'right'}, action = right, reward = 2.0, success = 1
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 18, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 1
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 17, inputs = {'light': 'green', 'waypoint': 'left'}, action = None, reward = 0.0, success = 1
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 16, inputs = {'light': 'green', 'waypoint': 'left'}, action = None, reward = 0.0, success = 1
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 15, inputs = {'light': 'red', 'waypoint': 'left'}, action = right, reward = -0.5, success = 1
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 14, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 1
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 13, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 1
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 12, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 1
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 11, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 1
# alpha = 0.1, gamma0.3
# Environment.act(): Primary agent has reached destination!
# LearningAgent.update(): deadline = 10, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 12.0, success = 2
# alpha = 0.1, gamma0.3
# Simulator.run(): Trial 3
# Environment.reset(): Trial set up with start = (2, 3), destination = (7, 2), deadline = 30
# RoutePlanner.route_to(): destination = (7, 2)
# LearningAgent.update(): deadline = 30, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 29, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 28, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 27, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 26, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 25, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 24, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 23, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 22, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 21, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 20, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 19, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 18, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 17, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 16, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 15, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 14, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 13, inputs = {'light': 'green', 'waypoint': 'left'}, action = right, reward = -0.5, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 12, inputs = {'light': 'green', 'waypoint': 'right'}, action = right, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 11, inputs = {'light': 'green', 'waypoint': 'right'}, action = right, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 10, inputs = {'light': 'green', 'waypoint': 'right'}, action = right, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 9, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 8, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 7, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 6, inputs = {'light': 'green', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 5, inputs = {'light': 'green', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 4, inputs = {'light': 'green', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 3, inputs = {'light': 'green', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 2, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 1, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 0, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Simulator.run(): Trial 4
# Environment.reset(): Trial set up with start = (1, 1), destination = (2, 5), deadline = 25
# RoutePlanner.route_to(): destination = (2, 5)
# LearningAgent.update(): deadline = 25, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 24, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 23, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 22, inputs = {'light': 'red', 'waypoint': 'left'}, action = forward, reward = -1.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 21, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 20, inputs = {'light': 'green', 'waypoint': 'left'}, action = forward, reward = -0.5, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 19, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 18, inputs = {'light': 'green', 'waypoint': 'right'}, action = right, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 17, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 16, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 15, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 2
# alpha = 0.1, gamma0.3
# Environment.act(): Primary agent has reached destination!
# LearningAgent.update(): deadline = 14, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 12.0, success = 3
# alpha = 0.1, gamma0.3
# Simulator.run(): Trial 5
# Environment.reset(): Trial set up with start = (2, 5), destination = (7, 5), deadline = 25
# RoutePlanner.route_to(): destination = (7, 5)
# LearningAgent.update(): deadline = 25, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 2.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 24, inputs = {'light': 'green', 'waypoint': 'forward'}, action = right, reward = -0.5, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 23, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 22, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 21, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 2.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 20, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 19, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 18, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 17, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 16, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 15, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 14, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 13, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 12, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 11, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 3
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 10, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 3
# alpha = 0.1, gamma0.3
# Environment.act(): Primary agent has reached destination!
# LearningAgent.update(): deadline = 9, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 12.0, success = 4
# alpha = 0.1, gamma0.3
# Simulator.run(): Trial 6
# Environment.reset(): Trial set up with start = (7, 6), destination = (1, 4), deadline = 40
# RoutePlanner.route_to(): destination = (1, 4)
# LearningAgent.update(): deadline = 40, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 39, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 38, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 37, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 2.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 36, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 35, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 34, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 33, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 32, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 31, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 30, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 29, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 28, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 27, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 26, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 4
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 25, inputs = {'light': 'red', 'waypoint': 'forward'}, action = left, reward = -1.0, success = 4
# alpha = 0.1, gamma0.3
# Environment.act(): Primary agent has reached destination!
# LearningAgent.update(): deadline = 24, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 12.0, success = 5
# alpha = 0.1, gamma0.3
# Simulator.run(): Trial 7
# Environment.reset(): Trial set up with start = (7, 2), destination = (5, 5), deadline = 25
# RoutePlanner.route_to(): destination = (5, 5)
# LearningAgent.update(): deadline = 25, inputs = {'light': 'green', 'waypoint': 'right'}, action = forward, reward = -0.5, success = 5
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 24, inputs = {'light': 'green', 'waypoint': 'right'}, action = right, reward = 2.0, success = 5
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 23, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 5
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 22, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 5
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 21, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 5
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 20, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 5
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 19, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 2.0, success = 5
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 18, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 5
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 17, inputs = {'light': 'red', 'waypoint': 'forward'}, action = left, reward = -1.0, success = 5
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 16, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 5
# alpha = 0.1, gamma0.3
# Environment.act(): Primary agent has reached destination!
# LearningAgent.update(): deadline = 15, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 12.0, success = 6
# alpha = 0.1, gamma0.3
# Simulator.run(): Trial 8
# Environment.reset(): Trial set up with start = (8, 3), destination = (1, 6), deadline = 50
# RoutePlanner.route_to(): destination = (1, 6)
# LearningAgent.update(): deadline = 50, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 49, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 48, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 47, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 46, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 45, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 2.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 44, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 43, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 42, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 41, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 40, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 39, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 38, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 37, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 36, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 35, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 34, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 33, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 32, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 31, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 30, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 2.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 29, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 28, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 6
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 27, inputs = {'light': 'red', 'waypoint': 'forward'}, action = forward, reward = -1.0, success = 6
# alpha = 0.1, gamma0.3
# Environment.act(): Primary agent has reached destination!
# LearningAgent.update(): deadline = 26, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 12.0, success = 7
# alpha = 0.1, gamma0.3
# Simulator.run(): Trial 9
# Environment.reset(): Trial set up with start = (2, 3), destination = (8, 6), deadline = 45
# RoutePlanner.route_to(): destination = (8, 6)
# LearningAgent.update(): deadline = 45, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 44, inputs = {'light': 'red', 'waypoint': 'forward'}, action = right, reward = -0.5, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 43, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 2.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 42, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 41, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 40, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 39, inputs = {'light': 'green', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 38, inputs = {'light': 'green', 'waypoint': 'forward'}, action = left, reward = -0.5, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 37, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 36, inputs = {'light': 'red', 'waypoint': 'forward'}, action = right, reward = -0.5, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 35, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 34, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 33, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 32, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 31, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 30, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 2.0, success = 7
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 29, inputs = {'light': 'red', 'waypoint': 'right'}, action = right, reward = 2.0, success = 7
# alpha = 0.1, gamma0.3
# Environment.act(): Primary agent has reached destination!
# LearningAgent.update(): deadline = 28, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 12.0, success = 8
# alpha = 0.1, gamma0.3
# Simulator.run(): Trial 10
# Environment.reset(): Trial set up with start = (5, 5), destination = (6, 2), deadline = 20
# RoutePlanner.route_to(): destination = (6, 2)
# LearningAgent.update(): deadline = 20, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 19, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 18, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 17, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 16, inputs = {'light': 'green', 'waypoint': 'forward'}, action = forward, reward = 2.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 15, inputs = {'light': 'red', 'waypoint': 'left'}, action = None, reward = 0.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 14, inputs = {'light': 'red', 'waypoint': 'left'}, action = right, reward = -0.5, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 13, inputs = {'light': 'green', 'waypoint': 'right'}, action = right, reward = 2.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 12, inputs = {'light': 'green', 'waypoint': 'right'}, action = right, reward = 2.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 11, inputs = {'light': 'green', 'waypoint': 'right'}, action = right, reward = 2.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 10, inputs = {'light': 'green', 'waypoint': 'left'}, action = left, reward = 2.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 9, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 8
# alpha = 0.1, gamma0.3
# LearningAgent.update(): deadline = 8, inputs = {'light': 'red', 'waypoint': 'forward'}, action = None, reward = 0.0, success = 8
